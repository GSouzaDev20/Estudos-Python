# %% [markdown]
# <a href="https://colab.research.google.com/github/GSouzaDev20/Estudos-Python/blob/main/Calculadora-Python/CalculadoraPy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print (f"==Calculadora==\n")

while True:

  print ("\n1 - Soma")
  print ("2 - Subtração")
  print ("3 - Multiplicação")
  print ("4 - Divisão")
  print ("0 - Sair")
  Operador = int(input(f"\nSelecione qual operador deseja utilizar!"))

  if Operador == 0:
    break
  Numero1 = int(input("\nDigite o primeiro número: "))
  Numero2 = int(input("\nDigite o segundo número: "))

  if Operador == 1:
    print(f"\nA soma dos dois números é {Numero1 + Numero2}")

  elif Operador == 2:
    print(f"\nA subtração dos dois números é {Numero1 - Numero2}")

  elif Operador == 3:
    print(f"\nA multiplicação dos dois números é {Numero1 * Numero2} ")

  elif Operador == 4:
    if Numero2 == 0:
      print(f"\nNão é possivel dividir por 0")
    else:
      print(f"\nA divisão dos dois números é {Numero1 / Numero2}")

  else:
    print(f"Operador invalido")

print(f"\nSistema encerrado")
# Out:
# ==Calculadora==
#
#
# 1 - Soma
# 2 - Subtração
# 3 - Multiplicação
# 4 - Divisão
# 0 - Sair
#
# Selecione qual operador deseja utilizar!4
#
# Digite o primeiro número: 0
#
# Digite o segundo número: 0
# /nNão é possivel dividir por 0
#
# 1 - Soma
# 2 - Subtração
# 3 - Multiplicação
# 4 - Divisão
# 0 - Sair
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-909145752.py in <cell line: 0>()
#       8   print ("4 - Divisão")
#       9   print ("0 - Sair")
# ---> 10   Operador = int(input(f"\nSelecione qual operador deseja utilizar!"))
#      11
#      12   if Operador == 0:
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
# ...
